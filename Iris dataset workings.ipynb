# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data = pd.read_csv(r"C:\Users\Asus\Downloads\iris dataset\Iris.csv")

# %%
iris_data
# Out:
#       Id  sepal_length  sepal_width  petal_length  petal_width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris_data.head()
# Out:
#    Id  sepal_length  sepal_width  petal_length  petal_width      species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_data.tail()
# Out:
#       Id  sepal_length  sepal_width  petal_length  petal_width         species
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris_data.describe()
# Out:
#                Id  sepal_length  sepal_width  petal_length  petal_width
# count  150.000000    149.000000   145.000000    150.000000   150.000000
# mean    75.500000      5.849664     3.055172      3.758667     1.198667
# std     43.445368      0.827208     0.439528      1.764420     0.763161
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
import pandas as pd

# Load dataset
iris_data = pd.read_csv(r"C:\Users\Asus\Downloads\iris dataset\Iris.csv")

# Check for missing values
missing_values = iris_data.isnull().sum()

# Display missing values per column
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Id              0
# sepal_length    1
# sepal_width     5
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
import pandas as pd

# Load dataset
iris_data = pd.read_csv(r"C:\Users\Asus\Downloads\iris dataset\Iris.csv")

# missing values before filling
print("Missing values before filling:\n", iris_data.isnull().sum())

# Fill missing values with mean
iris_data.fillna(df.mean(numeric_only=True), inplace=True)

# missing values after filling
print("\nMissing values after filling:\n", iris_data.isnull().sum())

# Display first few rows of the updated dataset
print("\nUpdated DataFrame:\n", iris_data.head(15))
# Out:
# Missing values before filling:
#  Id              0
# sepal_length    1
# sepal_width     5
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# Missing values after filling:
#  Id              0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# Updated DataFrame:
#      Id  sepal_length  sepal_width  petal_length  petal_width      species
# 0    1           5.1        3.500           1.4          0.2  Iris-setosa
# 1    2           4.9        3.000           1.4          0.2  Iris-setosa
# 2    3           4.7        3.200           1.3          0.2  Iris-setosa
# 3    4           4.6        3.100           1.5          0.2  Iris-setosa
# 4    5           5.0        3.600           1.4          0.2  Iris-setosa
# 5    6           5.4        3.900           1.7          0.4  Iris-setosa
# 6    7           4.6        3.400           1.4          0.3  Iris-setosa
# ...

# %%
import pandas as pd
import numpy as np

# Load dataset
iris_data = pd.read_csv(r"C:\Users\Asus\Downloads\iris dataset\Iris.csv")

# Add a new column with a value to calculate sepal length
iris_data["sepal_area"] = iris_data["sepal_length"] * iris_data["sepal_width"] 

# Add a new column with a value to calculate petal length
iris_data["petal_area"] = iris_data["petal_length"] * iris_data["petal_width"] 

# Add a new column with a value to calculate ratio
iris_data["ratio"] = iris_data["sepal_area"] / iris_data["petal_area"]

# Display updated Data
print(iris_data.head())
# Out:
#    Id  sepal_length  sepal_width  petal_length  petal_width      species  \
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa
#
#    sepal_area  petal_area      ratio
# 0       17.85        0.28  63.750000
# 1       14.70        0.28  52.500000
# 2       15.04        0.26  57.846154
# 3       14.26        0.30  47.533333
# 4       18.00        0.28  64.285714

# %%
from sklearn.preprocessing import LabelEncoder
#initialize LabelEncoder
le=LabelEncoder()
#encode the species column
iris_data['species_encoded'] = le.fit_transform(iris_data['species'])
#updated data
print(iris_data.head(100))
# Out:
#      Id  sepal_length  sepal_width  petal_length  petal_width  \
# 0     1           5.1          3.5           1.4          0.2
# 1     2           4.9          3.0           1.4          0.2
# 2     3           4.7          3.2           1.3          0.2
# 3     4           4.6          3.1           1.5          0.2
# 4     5           5.0          3.6           1.4          0.2
# ..  ...           ...          ...           ...          ...
# 95   96           5.7          3.0           4.2          1.2
# 96   97           5.7          2.9           4.2          1.3
# 97   98           6.2          2.9           4.3          1.3
# 98   99           5.1          2.5           3.0          1.1
# 99  100           5.7          2.8           4.1          1.3
#
#             species  species_encoded
# 0       Iris-setosa                0
# 1       Iris-setosa                0
# 2       Iris-setosa                0
# 3       Iris-setosa                0
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Compute correlation matrix 
correlation_matrix = iris_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(iris_data, height=2.5, hue="species")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
# Define feature matrix (X) - Exclude 'Species' from scaling
X = iris_data.drop(columns=['Species'])  

# Apply MinMaxScaler
min_max_scaler = MinMaxScaler()
X_minmax = min_max_scaler.fit_transform(X)

# Convert back to DataFrame with original column names
df_minmax = pd.DataFrame(X_minmax, columns=X.columns)

# Display normalized data
print("Min-Max Normalized Data:\n", df_minmax.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 3
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 # Define feature matrix (X) - Exclude 'Species' from scaling
# ----> 3 X = iris_data.drop(columns=['Species'])
#       5 # Apply MinMaxScaler
#       6 min_max_scaler = MinMaxScaler()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
# ...
